# %%
def allindices(string, sub, listindex=[], offset=0):
    i = string.find(sub, offset)
    while i >= 0:
        listindex.append(i)
        i = string.find(sub, i + 1)
    return listindex
operators = ('+', '-', '*', '/', '**')
solutions = []
counter = 0
for o1 in operators:
    for o2 in operators:
        for o3 in operators:
            for o4 in operators:
                exp = 'lambda : 5' + o1 + '2' + o2 + '3' + o3 + '5' + o4 + '2'
                fnc = eval(exp)
                if len(allindices(exp, '**', [])) > 2:
                    continue
                if fnc() == 50:
                    solutions.append(exp)
                print exp
print 'done'
print solutions
# Out:
# lambda : 5+2+3+5+2
# lambda : 5+2+3+5-2
# lambda : 5+2+3+5*2
# lambda : 5+2+3+5/2
# lambda : 5+2+3+5**2
# lambda : 5+2+3-5+2
# lambda : 5+2+3-5-2
# lambda : 5+2+3-5*2
# lambda : 5+2+3-5/2
# lambda : 5+2+3-5**2
# lambda : 5+2+3*5+2
# lambda : 5+2+3*5-2
# lambda : 5+2+3*5*2
# lambda : 5+2+3*5/2
# lambda : 5+2+3*5**2
# lambda : 5+2+3/5+2
# lambda : 5+2+3/5-2
# lambda : 5+2+3/5*2
# lambda : 5+2+3/5/2
# lambda : 5+2+3/5**2
# lambda : 5+2+3**5+2
# lambda : 5+2+3**5-2
# lambda : 5+2+3**5*2
# lambda : 5+2+3**5/2
# lambda : 5+2+3**5**2
# lambda : 5+2-3+5+2
# lambda : 5+2-3+5-2
# lambda : 5+2-3+5*2
# lambda : 5+2-3+5/2
# lambda : 5+2-3+5**2
# lambda : 5+2-3-5+2
# lambda : 5+2-3-5-2
# lambda : 5+2-3-5*2
# lambda : 5+2-3-5/2
# lambda : 5+2-3-5**2
# lambda : 5+2-3*5+2
# lambda : 5+2-3*5-2
# lambda : 5+2-3*5*2
# lambda : 5+2-3*5/2
# lambda : 5+2-3*5**2
# lambda : 5+2-3/5+2
# lambda : 5+2-3/5-2
# lambda : 5+2-3/5*2
# lambda : 5+2-3/5/2
# lambda : 5+2-3/5**2
# lambda : 5+2-3**5+2
# ...
